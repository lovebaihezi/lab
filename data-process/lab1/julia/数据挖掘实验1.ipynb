# %%
filePaths = "./" <> #& /@ {
    "xian_guangdian.xls", 
    "xian_beijing_salary.xlsx",
    "3movie_metadata.csv",
    "4ReaderRentRecode.csv",
    "4ReaderInformation.csv",
    "5iris.csv"
};
{file1, file2, file3, file41, file42, file5} = Import /@ filePaths;

# %%
salary = Delete[#, 1] &/@ Delete[Part[file2, 1], 2];
salary = Delete[Delete[#, 1] &/@ salary, 1];
DistributionChart @ {Part[#, 1]&/@salary, Part[#, 2]&/@salary}
BoxWhiskerChart @ {Part[#, 1]&/@salary, Part[#, 2]&/@salary}
DistributionChart@salary
BoxWhiskerChart@salary
# Out:
# -Graphics-
# -Graphics-
# -Graphics-
# -Graphics-

# %%
(* description = Part[file3, 1]; *)
(* movie = Delete[file3, 1]; *)
