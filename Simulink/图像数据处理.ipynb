# %%
image = CurrentImage[]
# Out:
# -Image-

# %%
ColorConvert[image, "GrayScale"]
# Out:
# -Image-

# %%
Binarize[ColorConvert[image, "GrayScale"], #]& /@ Range[0.2, 0.3, 0.01]
# Out:
# {-Image-, -Image-, -Image-, -Image-, -Image-, -Image-, -Image-, -Image-, -Image-,
#
# >   -Image-, -Image-}

# %%
EdgeDetect[ColorConvert[image, "GrayScale"]]
# Out:
# -Image-
