# %%
Import["./Arch3.png", "Summary"]
(* 读取图像信息 *)
image = ImageResize[
    ImageTake[Import["./Arch3.png"], {91, 2010}, {1861, 3780}], {256, 256}
]
(* 读取图像, 取1920*1920大小, 在将其转换为256大小 *)
ColorSeparate[image]
(* 取其四通道灰度图像 *)
ColorConvert[image, "GrayScale"]
(* 根据颜色转换为灰度图像 *)
Information@ColorConvert[image, "GrayScale"]
# Out:
# Dataset[<|Thumbnail -> -Image-, Format -> PNG, ImageCount -> 1,
#
# >    ImageSize -> {3840, 2160}, ColorSpace -> RGBColor, Channels -> 4, BitDepth -> 8,
#
# >    FileName -> Arch3.png, FileSize -> 9.1 megabytes|>,
#
# >   TypeSystem`Struct[{Thumbnail, Format, ImageCount, ImageSize, ColorSpace, Channels,
#
# >     BitDepth, FileName, FileSize},
#
# >    {TypeSystem`Atom[Image], TypeSystem`Atom[String], TypeSystem`Atom[Integer],
#
# >     TypeSystem`Vector[TypeSystem`Atom[Integer], 2], TypeSystem`AnyType,
#
# >     TypeSystem`Atom[Integer], TypeSystem`Atom[Integer], TypeSystem`Atom[String],
#
# >     TypeSystem`Atom[1 megabyte]}], <||>]
# -Image-
# {-Image-, -Image-, -Image-, -Image-}
# -Image-
# ObjectType        Image
# ColorSpace        Grayscale
# ImageDimensions   {256, 256}
# ImageResolution   {72, 72}
# Channels          2
# Interleaving      True
# Transparency      True
# DataType          Byte

# %%
first
# Out:
# -Image-

# %%
second
# Out:
# -Image-

# %%
third
# Out:
# -Image-

# %%
Thumbnail@image
(* 将Rgb图像转换为索引图 *)
# Out:
# -Image-

# %%
Import["./image.tiff", "Summary"]
indexImage = Import["./image.tiff"]
(* 读取本地tiff图像与信息 *)
# Out:
# Dataset[<|Thumbnail -> -Image-, Format -> TIFF, ImageCount -> 1, ImageSize -> {150, 81},
#
# >    ColorSpace -> RGBColor, Channels -> 3, BitDepth -> 8,
#
# >    DateTime -> DateObject[{2021, 10, 8, 9, 6, 33.}, Instant, Gregorian, 8.],
#
# >    FileName -> image.tiff, FileSize -> 21.8 kilobytes|>,
#
# >   TypeSystem`Struct[{Thumbnail, Format, ImageCount, ImageSize, ColorSpace, Channels,
#
# >     BitDepth, DateTime, FileName, FileSize},
#
# >    {TypeSystem`Atom[Image], TypeSystem`Atom[String], TypeSystem`Atom[Integer],
#
# >     TypeSystem`Vector[TypeSystem`Atom[Integer], 2], TypeSystem`AnyType,
#
# >     TypeSystem`Atom[Integer], TypeSystem`Atom[Integer], TypeSystem`Atom[DateObject],
#
# >     TypeSystem`Atom[String], TypeSystem`Atom[1 kilobyte]}], <||>]
# -Image-

# %%
{R, G, B} = ColorSeparate@indexImage
# Out:
# {-Image-, -Image-, -Image-}

# %%
Image@indexImage
# Out:
# -Image-

# %%
tank = Thumbnail@ExampleData[{"TestImage", "Tank"}]
# Out:
# -Image-

# %%
Binarize[tank]
Binarize[tank, #]& /@ Range[0, 1, 0.1]
(* 如果图像选择不正确, 则会导致重要信息丢失 *)
# Out:
# -Image-
# {-Image-, -Image-, -Image-, -Image-, -Image-, -Image-, -Image-, -Image-, -Image-,
#
# >   -Image-, -Image-}

# %%
image1 = Image[Table[Table[Table[RandomInteger[256], 3], 256], 256]]
Information@image1
Thumbnail@image1
Information@Thumbnail@image1
# Out:
# -Image-
# ObjectType        Image
# ColorSpace        Automatic
# ImageDimensions   {256, 256}
# ImageResolution   Automatic
# Channels          3
# Interleaving      True
# Transparency      False
# DataType          Real32
# -Image-
# ObjectType        Image
# ColorSpace        RGB
# ImageDimensions   {150, 150}
# ImageResolution   Automatic
# Channels          3
# Interleaving      True
# Transparency      False
# DataType          Real32

# %%
Import["./out.mp4", "Summary"]
# Out:
# Dataset[<|SampleFrame -> -Image-, Format -> MP4, Duration -> 0.48 seconds,
#
# >    VideoEncoding -> H264, RasterSize -> {1920, 1080},
#
# >    FrameRate -> 25 frames per second, FileName -> out.mp4,
#
# >    FileSize -> 4.41279 megabytes|>,
#
# >   TypeSystem`Struct[{SampleFrame, Format, Duration, VideoEncoding, RasterSize,
#
# >     FrameRate, FileName, FileSize},
#
# >    {TypeSystem`Atom[Image], TypeSystem`Atom[String], TypeSystem`Atom[1 second],
#
# >     TypeSystem`Atom[String], TypeSystem`Vector[TypeSystem`Atom[Integer], 2],
#
# >     TypeSystem`Atom[1 frame per second], TypeSystem`Atom[String],
#
# >     TypeSystem`Atom[1 megabyte]}], <||>]

# %%
video = Import["./out.mp4"];
VideoFrameList[video, 10]
# Out:
# Extracting video frames... [================                        ] Elapsed time: 4s | Remaining time: 6s
#
# Extracting video frames... [================                        ] Elapsed time: 4s | Remaining time: 6s
#
# Extracting video frames... [================                        ] Elapsed time: 5s | Remaining time: 6s
#
# Extracting video frames... [====================                    ] Elapsed time: 5s | Remaining time: 5s
#
# Extracting video frames... [====================                    ] Elapsed time: 6s | Remaining time: 5s
#
# Extracting video frames... [========================                ] Elapsed time: 6s | Remaining time: 4s
#
# Extracting video frames... [============================            ] Elapsed time: 6s | Remaining time: 3s
#
# Extracting video frames... [============================            ] Elapsed time: 7s | Remaining time: 3s
#
# ...
